# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
import pytesseract
from PIL import Image

# Load an image
img = Image.open('image.png')

# Apply OCR
text = pytesseract.image_to_string(img)

print(text)
# Out:
# EFTAKHER ALAM
#
# GRAPHIC DESIGNER
#
# Night after night, she came to tuck me in,
# ‘even long after my childhood years.
#
# Following her longstanding custom,
#
# she'd lean down and push my long hair out of the way,
# then kiss my forehead, [don't
#
# ABOUT ME ———
#
# Lorem ipsum dolor sit amet, consectetur
# adipiecing elt, Praesent eget massa vel
# ‘augue tempus egestas sit amet sed nulla,
# Pain bibendum est non magna finbus, i
# tincidunt enim sodales. rusce viverra
# placerat enim. Nam tincidunt augue nec nulla
# Ssolitudn vitae posuere felis condimentum,
# Duis amattisnune, ut posuere magna. Fusce
# fed faucibus est Mauris sed urna at magna
# faucibus aliquet non ut tellus. Donec porta,
# vei sitamet scelerisque molestie, iber ante
# Tempus nis, vitae commodo lectus tortor
# Dlandltlectus.
#
# Lorem ipsum dolor sit amet, consectetur
# adipiscing elt. Praesent eget massa
#
# CONTACT ———
# +000 000 00000
#
# your address line here
# youremail@gmail.com
#
# company_name@.com
#
# ©0006
#
# www.twitter.com/user
#
# www. facebook.com/user
#
# SKILLS
#
# Skill Ot
#
# ——:
# —
#
# —
#
# FORMALEDUCTION
#
# 2004-05 DEGREE NAME
# UNIVERSITY NAME
# Loxem ipsam doar at met. cossceur apna et
#
# 2007-09 DEGREE NAME
# UNIVERSITY NAME
#
# 2010-12 DEGREE NAME
# UNIVERSITY NAME
#
# PROFESSIONALEXPERIENCE
#
# 2019-14 JOB TITLES
# COMPANY NAME
#
# 2014-15 JOB TITLES
# COMPANY NAME
#
# 2015-16 JOB TITLES
# COMPANY NAME
#
# Love ipsum doo st are coneceeapcig elt
#
# Designed by Pngtree
